# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/crime-learn/crime_test.csv
# /kaggle/input/crime-learn/sample_submission.csv
# /kaggle/input/crime-learn/crime_train.csv

# %%
df= pd.read_csv('/kaggle/input/crime-learn/sample_submission.csv')
df
# Out:
#       ID  Prediction
# 0      1           1
# 1      2           1
# 2      3           1
# 3      4           1
# 4      5           1
# ..   ...         ...
# 394  395           1
# 395  396           1
# 396  397           1
# 397  398           1
# 398  399           1
#
# [399 rows x 2 columns]

# %%
test_data = pd.read_csv('/kaggle/input/crime-learn/crime_test.csv')
test_data
# Out:
#       ID  population  householdsize  agePct12t21  agePct12t29  agePct16t24  \
# 0      1       11874           2.11        10.54        30.87        14.08
# 1      2       14143           2.68        21.01        33.35        21.95
# 2      3       34882           2.32        12.56        21.79        11.29
# 3      4       29885           3.53        20.10        34.33        18.31
# 4      5      935933           2.86        15.89        30.35        14.98
# ..   ...         ...            ...          ...          ...          ...
# 394  395       11096           2.40        26.67        47.49        36.51
# 395  396       11843           2.45        12.77        24.08        11.09
# 396  397       33892           2.80        16.81        28.88        13.91
# 397  398       29060           2.76        15.46        27.15        12.78
# 398  399       12567           2.51        13.03        20.15         9.21
#
# ...

# %%
test_data.shape
# Out:
# (399, 89)

# %%
train_data = pd.read_csv('/kaggle/input/crime-learn/crime_train.csv')
train_data
# Out:
#         ID  population  householdsize  agePct12t21  agePct12t29  agePct16t24  \
# 0        1       14985           2.56        16.55        34.42        22.54
# 1        2       30843           2.83        15.45        35.12        18.14
# 2        3       74991           2.52        10.48        20.43         9.11
# 3        4       45061           2.44        10.59        24.97        11.61
# 4        5       12863           2.45        12.02        22.51        10.49
# ...    ...         ...            ...          ...          ...          ...
# 1590  1591      372242           2.58        12.88        27.02        12.96
# 1591  1592       49389           2.56        11.17        22.59        10.65
# 1592  1593      131591           2.62        12.40        28.85        13.61
# 1593  1594      165121           2.36        16.31        32.25        18.75
# 1594  1595       30601           2.41        11.08        22.59        10.15
#
# ...

# %%
train_data.shape
# Out:
# (1595, 90)

# %%
test_data.corr()
# Out:
#                         ID  population  householdsize  agePct12t21  \
# ID                1.000000   -0.104767       0.015711    -0.004221
# population       -0.104767    1.000000      -0.000866    -0.001917
# householdsize     0.015711   -0.000866       1.000000     0.495704
# agePct12t21      -0.004221   -0.001917       0.495704     1.000000
# agePct12t29      -0.000303    0.066482       0.365499     0.861744
# ...                    ...         ...            ...          ...
# PctForeignBorn    0.018364    0.083432       0.381281    -0.050914
# PctBornSameState -0.030716   -0.030117      -0.069128     0.047258
# PctSameHouse85   -0.014207   -0.037796      -0.068009    -0.381894
# PctSameCity85    -0.054866    0.025825      -0.094316    -0.436794
# PctSameState85   -0.005691   -0.018532      -0.003121    -0.238510
#
#                   agePct12t29  agePct16t24  agePct65up  numbUrban  pctUrban  \
# ID                  -0.000303    -0.009048   -0.022464  -0.104126  0.027082
# ...

# %%
X_train =train_data.iloc[:,:-2].values
X_train
# Out:
# array([[1.00000e+00, 1.49850e+04, 2.56000e+00, ..., 6.09400e+01,
#         4.72800e+01, 6.66500e+01],
#        [2.00000e+00, 3.08430e+04, 2.83000e+00, ..., 2.52400e+01,
#         2.81700e+01, 5.27300e+01],
#        [3.00000e+00, 7.49910e+04, 2.52000e+00, ..., 1.36900e+01,
#         3.44900e+01, 6.08800e+01],
#        ...,
#        [1.59300e+03, 1.31591e+05, 2.62000e+00, ..., 3.91300e+01,
#         4.58700e+01, 8.09500e+01],
#        [1.59400e+03, 1.65121e+05, 2.36000e+00, ..., 6.95700e+01,
#         4.78600e+01, 7.77700e+01],
#        [1.59500e+03, 3.06010e+04, 2.41000e+00, ..., 6.92100e+01,
#         6.02900e+01, 8.84400e+01]])

# %%
y_train = train_data.iloc[:,-1].values
y_train
# Out:
# array([ 428.64,  742.54,  303.72, ..., 1280.74, 1693.42,  271.52])

# %%
X_test= test_data.iloc[:,:-1].values
X_test
# Out:
# array([[1.0000e+00, 1.1874e+04, 2.1100e+00, ..., 5.1780e+01, 3.9890e+01,
#         7.5630e+01],
#        [2.0000e+00, 1.4143e+04, 2.6800e+00, ..., 7.5910e+01, 5.1790e+01,
#         7.2200e+01],
#        [3.0000e+00, 3.4882e+04, 2.3200e+00, ..., 7.4430e+01, 6.2600e+01,
#         8.6350e+01],
#        ...,
#        [3.9700e+02, 3.3892e+04, 2.8000e+00, ..., 6.0920e+01, 6.6230e+01,
#         9.2980e+01],
#        [3.9800e+02, 2.9060e+04, 2.7600e+00, ..., 6.6470e+01, 5.7270e+01,
#         7.7550e+01],
#        [3.9900e+02, 1.2567e+04, 2.5100e+00, ..., 1.2950e+01, 3.9770e+01,
#         6.5910e+01]])

# %%
from sklearn.linear_model import LinearRegression  
reg = LinearRegression()
reg.fit(X_train, y_train)
reg.coef_
# Out:
# array([-2.58983167e-02,  5.98610368e-04,  3.93913680e+01, -8.25446307e+00,
#        -3.56595899e+01,  3.27817328e+01, -1.27520193e+01, -7.50101583e-04,
#         1.38179343e+00, -2.20463413e-02, -6.62454985e+00,  2.68934011e+01,
#        -6.90920874e+00,  1.18473315e+01,  8.58442358e+00, -7.65771896e+00,
#         1.70722804e-02, -3.84400452e-03, -2.66059903e-03, -2.51227056e+00,
#        -1.37504018e+01,  4.61023933e+00,  1.84965883e+00, -1.28111753e+00,
#         1.28149000e+01, -4.08394826e+00,  1.99262060e+00, -6.19188075e-01,
#         4.27435541e+00,  1.97882720e+02, -2.14729832e+00,  1.41754966e+02,
#        -3.29339509e+02, -3.73255314e+02, -1.63944528e+00, -1.98462830e+01,
#         2.91682481e+00, -7.00164250e-01,  3.45151289e+00, -1.04893519e+01,
#        -1.43173712e-03,  5.75012594e+01,  8.36675148e-04,  2.55842799e+00,
#        -1.43752771e+00,  1.58655818e-01,  9.82441693e-01, -3.53232157e+01,
# ...

# %%
reg.intercept_
# Out:
# 985.6090486526531

# %%
reg.score(X_train, y_train)
# Out:
# 0.6649581139874827

# %%
final = reg.predict(X_test)
final
# Out:
# array([ 791.05347807,  389.2285448 ,  660.24398449,  828.81886148,
#        1053.66922174,  233.4682354 , 1181.34741922,  163.72565941,
#        1422.74025878,  911.81126132,  259.42587742,  410.96090468,
#         127.79470024,  293.75960716, 1074.83624409, 1333.90056718,
#         798.81067516,  343.47970167, 1387.86053642, 1646.12929397,
#         394.13073964,  415.0757241 , 1066.4688928 ,  100.79716059,
#         927.20105761,  201.5808683 , 1073.32841725,  668.545465  ,
#         415.18085922,  344.20240243,  266.56206749,  319.02458967,
#         194.89471739,  478.68957185,  411.4518414 ,   68.81397486,
#         155.55005587,  316.12604764,  972.61585052,   20.45571705,
#         -62.18508602, 1500.00801139,  188.66345565,  437.15464998,
#        1068.28285869,   93.58719305,  618.25416085,  175.04355294,
#         825.56535623,  222.71063765,  852.68223452,  452.48032262,
#         970.74695553,  652.73046139, -120.36337551,  578.80599581,
# ...

# %%
final_output = pd.DataFrame({'ID':test_data['ID'],'Prediction':np.array(final)})

# %%
final_output.to_csv("crime_final_output.csv")
